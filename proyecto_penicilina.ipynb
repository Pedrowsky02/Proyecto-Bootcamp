# %% [markdown]
# ## Carga de Datos y Limpieza

# %%
import math
import numpy as np
import pandas as pd

# %%
data_Stats=pd.read_csv('data/100_Batches_IndPenSim_Statistics.csv',index_col=0)
data_B1=pd.read_csv('data/100_Batches_IndPenSim_V3.csv',index_col=0)

# %%
data_B1['2-PAT control(PAT_ref:PAT ref)'] #Referencia del lote (1 al 100)
# Out:
# Time (h)
# 0.2        1
# 0.4        1
# 0.6        1
# 0.8        1
# 1.0        1
# 1.2        1
# 1.4        1
# 1.6        1
# 1.8        1
# 2.0        1
# 2.2        1
# 2.4        1
# 2.6        1
# 2.8        1
# 3.0        1
# 3.2        1
# 3.4        1
# 3.6        1
# 3.8        1
# 4.0        1
# 4.2        1
# 4.4        1
# 4.6        1
# 4.8        1
# 5.0        1
# 5.2        1
# 5.4        1
# 5.6        1
# 5.8        1
# 6.0        1
# 6.2        1
# 6.4        1
# 6.6        1
# 6.8        1
# 7.0        1
# 7.2        1
# 7.4        1
# 7.6        1
# 7.8        1
# 8.0        1
# 8.2        1
# 8.4        1
# 8.6        1
# 8.8        1
# 9.0        1
# 9.2        1
# 9.4        1
# 9.6        1
# 9.8        1
# 10.0       1
# 10.2       1
# 10.4       1
# 10.6       1
# 10.8       1
# 11.0       1
# 11.2       1
# 11.4       1
# 11.6       1
# 11.8       1
# 12.0       1
# 12.2       1
# 12.4       1
# 12.6       1
# 12.8       1
# 13.0       1
# ...
